# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None) # to see all columns in a wide DataFrame
import time
import numpy as np

# %%
test_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2015-16&SeasonType=Regular%20Season&StatCategory=PTS'
r = requests.get(url=test_url).json()

# %%
table_headers = r['resultSet']['headers']

# %%
pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
# Out:
#      PLAYER_ID  RANK               PLAYER     TEAM_ID TEAM  GP   MIN   FGM  \
# 0       201939     1        Stephen Curry  1610612744  GSW  79  34.2  10.2
# 1       201935     2         James Harden  1610612745  HOU  82  38.1   8.7
# 2       201142     3         Kevin Durant  1610612760  OKC  72  35.8   9.7
# 3       202326     4     DeMarcus Cousins  1610612758  SAC  65  34.6   9.2
# 4         2544     5         LeBron James  1610612739  CLE  76  35.6   9.7
# ..         ...   ...                  ...         ...  ...  ..   ...   ...
# 266     203948   267  Johnny O'Bryant III  1610612749  MIL  66  13.0   1.3
# 267     203187   268        Chris Johnson  1610612762  UTA  70  12.2   1.0
# 268       2419   269      Tayshaun Prince  1610612750  MIN  77  19.0   1.3
# 269     203143   270       Pablo Prigioni  1610612746  LAC  59  13.9   0.9
# 270       2555   271        Nick Collison  1610612760  OKC  59  11.8   0.8
#
# ...

# %%
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8,id;q=0.7',
    'Connection': 'keep-alive',
    'Host': 'stats.nba.com',
    'Origin': 'https://www.nba.com',
    'Referer': 'https://www.nba.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': "Windows"
}

# %%
df_cols = ['Year', 'Season_type'] + table_headers
df = pd.DataFrame(columns=df_cols)
season_types = ['Regular%20Season', 'Playoffs']
years = ['2015-16', '2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24']

begin_loop = time.time()

for y in years:
    for s in season_types:
        api_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season='+y+'&SeasonType='+s+'&StatCategory=PTS'
        r = requests.get(url=api_url).json()
        temp_df1 = pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
        # temp_df1 = temp_df1.drop(['TEAM_ID'], axis=1)
        temp_df2 = pd.DataFrame({'Year':[y for i in range(len(temp_df1))],
                                'Season_type':[s for i in range(len(temp_df1))]})
        temp_df3 = pd.concat([temp_df2, temp_df1], axis=1)
        df = pd.concat([df, temp_df3], axis=0)
        print(f'Finished scraping data for the {y} {s}.')
        lag = np.random.uniform(low=5, high=40)
        print(f'...waiting {round(lag, 1)} seconds')
        time.sleep(lag)
print(f'Process completed! Total run time: {round((time.time() - begin_loop)/60, 2)}')

df.to_csv("nba_player_stats.csv", index=False)
# Out:
# C:\Users\jorda\AppData\Local\Temp\ipykernel_33636\3217051303.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, temp_df3], axis=0)
# Finished scraping data for the 2015-16 Regular%20Season.
# ...waiting 21.8 seconds
# Finished scraping data for the 2015-16 Playoffs.
# ...waiting 15.4 seconds
# Finished scraping data for the 2016-17 Regular%20Season.
# ...waiting 19.2 seconds
# Finished scraping data for the 2016-17 Playoffs.
# ...waiting 20.8 seconds
# Finished scraping data for the 2017-18 Regular%20Season.
# ...waiting 13.2 seconds
# Finished scraping data for the 2017-18 Playoffs.
# ...waiting 11.4 seconds
# Finished scraping data for the 2018-19 Regular%20Season.
# ...waiting 34.4 seconds
# ...

# %%
df = pd.read_csv("csv files/nba_player_stats.csv", index_col=0)
df
# Out:
#               Season_type  PLAYER_ID  RANK            PLAYER     TEAM_ID TEAM  \
# Year
# 2015-16  Regular%20Season     201939     1     Stephen Curry  1610612744  GSW
# 2015-16  Regular%20Season     201935     2      James Harden  1610612745  HOU
# 2015-16  Regular%20Season     201142     3      Kevin Durant  1610612760  OKC
# 2015-16  Regular%20Season     202326     4  DeMarcus Cousins  1610612758  SAC
# 2015-16  Regular%20Season       2544     5      LeBron James  1610612739  CLE
# ...                   ...        ...   ...               ...         ...  ...
# 2023-24          Playoffs    1629626   136           Bol Bol  1610612756  PHX
# 2023-24          Playoffs    1629026   137  Kenrich Williams  1610612760  OKC
# 2023-24          Playoffs    1629637   138      Jaxson Hayes  1610612747  LAL
# 2023-24          Playoffs     202330   139    Gordon Hayward  1610612760  OKC
# 2023-24          Playoffs    1641722   139    Jordan Hawkins  1610612740  NOP
#
# ...

# %%
overall_rankings_table = df.drop(columns=["PLAYER_ID", "TEAM_ID"], axis=0)

# %%
overall_rankings_table
# Out:
#               Season_type  RANK            PLAYER TEAM  GP   MIN   FGM   FGA  \
# Year
# 2015-16  Regular%20Season     1     Stephen Curry  GSW  79  34.2  10.2  20.2
# 2015-16  Regular%20Season     2      James Harden  HOU  82  38.1   8.7  19.7
# 2015-16  Regular%20Season     3      Kevin Durant  OKC  72  35.8   9.7  19.2
# 2015-16  Regular%20Season     4  DeMarcus Cousins  SAC  65  34.6   9.2  20.5
# 2015-16  Regular%20Season     5      LeBron James  CLE  76  35.6   9.7  18.6
# ...                   ...   ...               ...  ...  ..   ...   ...   ...
# 2023-24          Playoffs   136           Bol Bol  PHX   3   4.3   0.3   1.0
# 2023-24          Playoffs   137  Kenrich Williams  OKC   7   4.4   0.3   1.1
# 2023-24          Playoffs   138      Jaxson Hayes  LAL   4   6.0   0.0   0.5
# 2023-24          Playoffs   139    Gordon Hayward  OKC   7   6.6   0.0   0.4
# 2023-24          Playoffs   139    Jordan Hawkins  NOP   3   4.0   0.0   1.3
#
# ...

# %%
overall_rankings_table.to_csv("nba_overall_rankings.csv", index=True)
